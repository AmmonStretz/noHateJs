# %%
# %run ../config.ipynb
# %run ./data_loader.ipynb
# %run ./helper_functions.ipynb
# %run ./diagramm_generator.ipynb
# %run ./metrics_generator.ipynb
# %run ./table_generator.ipynb

# %%
#config data
test
# Out:
# 'Ammon'

# %%
data = load_data('../data/predictions.json')

# %%
dictionary
# Out:
# {'Die': {'count': 122, 'tp': 32, 'tn': 47, 'fp': 24, 'fn': 18},
#  'von': {'count': 181, 'tp': 54, 'tn': 59, 'fp': 42, 'fn': 25},
#  'dem': {'count': 87, 'tp': 19, 'tn': 36, 'fp': 22, 'fn': 9},
#  'Leiter': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0},
#  'im': {'count': 78, 'tp': 23, 'tn': 24, 'fp': 21, 'fn': 9},
#  'Artikel': {'count': 11, 'tp': 3, 'tn': 1, 'fp': 2, 'fn': 4},
#  'gebrachten': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0},
#  'Stichworte': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0},
#  'lassen': {'count': 12, 'tp': 4, 'tn': 5, 'fp': 0, 'fn': 2},
#  'allerdings': {'count': 4, 'tp': 2, 'tn': 1, 'fp': 0, 'fn': 0},
#  'leise': {'count': 2, 'tp': 1, 'tn': 0, 'fp': 0, 'fn': 0},
#  'Zweifel': {'count': 2, 'tp': 0, 'tn': 0, 'fp': 1, 'fn': 0},
#  'aufkommen': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0},
#  ',': {'count': 1257, 'tp': 333, 'tn': 500, 'fp': 290, 'fn': 133},
#  'ob': {'count': 11, 'tp': 5, 'tn': 4, 'fp': 0, 'fn': 1},
# ...
