# %% [markdown]
# # Single word metrics #

# %%
#in this script all the display functions are defined
# %run functions-spacy.ipynb
# Out:
# {'lassen': {'count': 12, 'tp': 4, 'tn': 5, 'fp': 0, 'fn': 2}, 'aufkommen': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'geht': {'count': 31, 'tp': 9, 'tn': 10, 'fp': 8, 'fn': 3}, 'scheint': {'count': 8, 'tp': 3, 'tn': 3, 'fp': 0, 'fn': 1}, 'behalten': {'count': 5, 'tp': 2, 'tn': 2, 'fp': 0, 'fn': 0}, 'wollen': {'count': 28, 'tp': 8, 'tn': 12, 'fp': 4, 'fn': 3}, 'bekommt': {'count': 3, 'tp': 0, 'tn': 2, 'fp': 0, 'fn': 0}, 'sinkt': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'heult': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'Geliefert': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'bestellt': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'gewählt': {'count': 2, 'tp': 0, 'tn': 0, 'fp': 1, 'fn': 0}, 'müst': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'muss': {'count': 18, 'tp': 9, 'tn': 4, 'fp': 4, 'fn': 0}, 'anziehen': {'count': 2, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 1}, 'verzichten': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'lebten': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'gelitten': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'verfügt': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'aussprechen': {'count': 2, 'tp': 0, 'tn': 1, 'fp': 0, 'fn': 0}, 'müssen': {'count': 24, 'tp': 8, 'tn': 6, 'fp': 8, 'fn': 1}, 'gefeiert': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'verdrängen': {'count': 2, 'tp': 0, 'tn': 1, 'fp': 0, 'fn': 0}, 'macht': {'count': 14, 'tp': 2, 'tn': 6, 'fp': 4, 'fn': 1}, 'verhindern': {'count': 6, 'tp': 2, 'tn': 0, 'fp': 2, 'fn': 1}, 'machen': {'count': 16, 'tp': 5, 'tn': 8, 'fp': 0, 'fn': 2}, 'betreibt': {'count': 3, 'tp': 1, 'tn': 0, 'fp': 1, 'fn': 0}, 'scheinen': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'vorzusorgen': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'bestreitet': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'gibt': {'count': 40, 'tp': 15, 'tn': 13, 'fp': 10, 'fn': 1}, 'handelt': {'count': 5, 'tp': 2, 'tn': 1, 'fp': 1, 'fn': 0}, 'stellen': {'count': 13, 'tp': 5, 'tn': 5, 'fp': 0, 'fn': 2}, 'konnte': {'count': 4, 'tp': 0, 'tn': 0, 'fp': 2, 'fn': 1}, 'einfordert': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'konsumiert': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'erwarten': {'count': 4, 'tp': 1, 'tn': 1, 'fp': 0, 'fn': 1}, 'schächten': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'halten': {'count': 13, 'tp': 6, 'tn': 4, 'fp': 2, 'fn': 0}, 'steinigen': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'bezeichnen': {'count': 5, 'tp': 0, 'tn': 2, 'fp': 1, 'fn': 1}, 'gelte': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'gerechnet': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'festgestellt': {'count': 2, 'tp': 0, 'tn': 0, 'fp': 1, 'fn': 0}, 'winkt': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'registrieren': {'count': 2, 'tp': 1, 'tn': 0, 'fp': 0, 'fn': 0}, 'lebenden': {'count': 2, 'tp': 1, 'tn': 0, 'fp': 0, 'fn': 0}, 'sollen': {'count': 19, 'tp': 6, 'tn': 7, 'fp': 2, 'fn': 3}, 'arbeiten': {'count': 10, 'tp': 0, 'tn': 4, 'fp': 4, 'fn': 1}, 'zahlen': {'count': 5, 'tp': 1, 'tn': 2, 'fp': 1, 'fn': 0}, 'sterben': {'count': 3, 'tp': 1, 'tn': 0, 'fp': 1, 'fn': 0}, 'verdanken': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'gesetzt': {'count': 4, 'tp': 1, 'tn': 0, 'fp': 1, 'fn': 1}, 'entscheiden': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'bricht': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'belangt': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'passiert': {'count': 2, 'tp': 0, 'tn': 1, 'fp': 0, 'fn': 0}, 'sollten': {'count': 8, 'tp': 4, 'tn': 1, 'fp': 2, 'fn': 0}, 'einsperren': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'steht': {'count': 13, 'tp': 4, 'tn': 4, 'fp': 2, 'fn': 2}, 'erreicht': {'count': 2, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 1}, 'diffamiert': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'unterzubringen': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'faselt': {'count': 1, 'tp': 0, 'tn': 0, 'fp': 0, 'fn': 0}, 'schmecken': {'count': 1, 'tp':  ...

# %%
import matplotlib
import matplotlib.pyplot as plt

d = dictionary_noun
max = 50

def countMap(el):
    return el[1]['count']

def accuracy(el):
    if (el[1]['tp'] + el[1]['tn'] + el[1]['fp'] + el[1]['fn']) == 0:
        return 0
    return (el[1]['tp'] + el[1]['tn']) / (el[1]['tp'] + el[1]['tn'] + el[1]['fp'] + el[1]['fn'])
def precision(el):
    if el[1]['tp'] + el[1]['fp'] == 0:
        return 0
    return el[1]['tp'] / (el[1]['tp'] + el[1]['fp'])

def recall(el):
    if el[1]['tp'] + el[1]['fn'] == 0:
        return 0
    return el[1]['tp'] / (el[1]['tp'] + el[1]['fn'])
def f1(el):
    if (recall(el) + precision(el)) == 0:
            return 0
    return (2 * (recall(el) * precision(el))) / (recall(el) + precision(el))

matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.set_xlim(0, max)
ax.plot(list(map(countMap, list(d.items()))), list(map(accuracy, list(d.items()))), 'o')
ax.set_title('accuracy')
plt.show()
            
matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.set_xlim(0, max)
ax.plot(list(map(countMap, list(d.items()))), list(map(f1, list(d.items()))), 'o')
ax.set_title('f1')
plt.show()

matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.set_xlim(0, max)
ax.plot(list(map(countMap, list(d.items()))), list(map(precision, list(d.items()))), 'o')
ax.set_title('precision')
plt.show()
            
matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.set_xlim(0, max)
ax.plot(list(map(countMap, list(d.items()))), list(map(recall, list(d.items()))), 'o')
ax.set_title('recall')
plt.show()
