# %% [markdown]
# # Single word metrics #

# %%
#in this script all the display functions are defined
# %run functions.ipynb
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Ammon
# [nltk_data]     Stretz\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import matplotlib
import matplotlib.pyplot as plt

def countMap(el):
    return el[1]['count']

def accuracy(el):
    if (el[1]['tp'] + el[1]['tn'] + el[1]['fp'] + el[1]['fn']) == 0:
        return 0
    return (el[1]['tp'] + el[1]['tn']) / (el[1]['tp'] + el[1]['tn'] + el[1]['fp'] + el[1]['fn'])
def precision(el):
    if el[1]['tp'] + el[1]['fp'] == 0:
        return 0
    return el[1]['tp'] / (el[1]['tp'] + el[1]['fp'])

def recall(el):
    if el[1]['tp'] + el[1]['fn'] == 0:
        return 0
    return el[1]['tp'] / (el[1]['tp'] + el[1]['fn'])
def f1(el):
    if (recall(el) + precision(el)) == 0:
            return 0
    return (2 * (recall(el) * precision(el))) / (recall(el) + precision(el))

matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.set_xlim(0, 200)
ax.plot(list(map(countMap, list(dictionary.items()))), list(map(accuracy, list(dictionary.items()))), 'o')
ax.set_title('accuracy')
plt.show()
            
matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.set_xlim(0, 200)
ax.plot(list(map(countMap, list(dictionary.items()))), list(map(f1, list(dictionary.items()))), 'o')
ax.set_title('f1')
plt.show()

matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.set_xlim(0, 200)
ax.plot(list(map(countMap, list(dictionary.items()))), list(map(precision, list(dictionary.items()))), 'o')
ax.set_title('precision')
plt.show()
            
matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.set_xlim(0, 200)
ax.plot(list(map(countMap, list(dictionary.items()))), list(map(recall, list(dictionary.items()))), 'o')
ax.set_title('recall')
plt.show()
